# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('mmafl_dmp_indexes.xlsx')

cutoff = df['index'].quantile(0.9)

above_cutoff_rows = df.loc[df['index'] > cutoff]

above_cutoff_rows
# Out:
#        data_provider_id  taxonomy_id taxonomy_entry_code  \
# 0                  8099        19631        ca_118099200
# 1                  8099        19631        ca_117965824
# 2                 11122        23387        POTTERY_BARN
# 3                 11122        23388           COMMUTERS
# 4                  8099        20427      apac_117637120
# 5                  8099        20427      apac_117637376
# 6                  8099        20427      apac_117769216
# 7                 11122        23388  ITALIAN_FOOD_DINER
# 8                  7612         7577           392187586
# 9                  7612         7577                8009
# 10                 7612         7577           406383987
# 11                 8099        20428     mena_3221618922
# 12                 8099        19631       ca_3222405383
# 13                 8099        20427      apac_117769472
# 14                 8099        20427      apac_117637632
# ...
