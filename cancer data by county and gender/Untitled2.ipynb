# %%
import pandas as pd
df = pd.read_excel('murano_dmp_pull2_2 (1).xlsx')

# %%
new_df = df[df.taxonomy_entry_category.str.find('Social Media Users') > -1]

print(new_df)

new_df.to_csv("filtered_murano_data_by_social_media.csv", sep=',', encoding='utf-8')
# Out:
#         data_provider_id  taxonomy_id taxonomy_entry_code data_provider_name  \
# 2125               11878        24667            14734663   AmeribaseDigital
# 2249               11878        24667            14734669   AmeribaseDigital
# 3118               11878        24667            14734665   AmeribaseDigital
# 4182               11878        24667            14734661   AmeribaseDigital
# 6199               11878        24667            14734671   AmeribaseDigital
# 6804               11878        24667            14734667   AmeribaseDigital
# 6920               11878        24667            14734659   AmeribaseDigital
# 7166               11878        24667            14734672   AmeribaseDigital
# 19870              11878        24667            14734663   AmeribaseDigital
# 21358              11878        24667            14734661   AmeribaseDigital
# 21585              11878        24667            14734667   AmeribaseDigital
# ...
