# %%
import pandas as pd
import math
df = pd.read_csv('FAGE URL Collection - Sheet1.csv')

import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np

# %%
from lxml import html  
import requests

cols = list(df.columns)[2:5]

print(cols)

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36'

col_dict = {}



for col in cols:
    reviews_df = []
    for url in df[col]:
        
#         print(url)
        if isinstance(url, float) is False and 'amazon' in url:
            headers = {'User-Agent': user_agent}
            page = requests.get(url, headers = headers)
            parser = html.fromstring(page.content)
            xpath_reviews = '//div[@data-hook="review"]'
            reviews = parser.xpath(xpath_reviews)
            xpath_rating  = './/i[@data-hook="review-star-rating"]//text()' 
            xpath_title   = './/a[@data-hook="review-title"]//text()'
            xpath_author  = './/a[@data-hook="review-author"]//text()'
            xpath_date    = './/span[@data-hook="review-date"]//text()'
            xpath_body    = './/span[@data-hook="review-body"]//text()'
            xpath_helpful = './/span[@data-hook="helpful-vote-statement"]//text()'

            for review in reviews:
                rating  = review.xpath(xpath_rating)
                title   = review.xpath(xpath_title)
                author  = review.xpath(xpath_author)
                date    = review.xpath(xpath_date)
                body    = review.xpath(xpath_body)
                helpful = review.xpath(xpath_helpful)
                
                
#                 print(body)
                
                word_tokens = word_tokenize(body[0])

                filtered_sentence = [w for w in word_tokens if not w in stop_words]

                filtered_sentence = []

                for w in word_tokens:
                    if w not in stop_words:
                        filtered_sentence.append(w)

                review_dict = {'rating': rating,
                               'title': title,
                               'author': author,             
                               'date': date,
                               'body': " ".join(filtered_sentence),
                               'helpful': helpful}
#                 print(review_dict)
                reviews_df.append(review_dict)
    print(reviews_df)    
    col_dict[col] = pd.DataFrame(reviews_df)
# Out:
# ['Plain Greek', 'Flavored Greek', 'Non Greek']
# [{'rating': ['3.0 out of 5 stars'], 'title': ['Poor packaging'], 'author': [], 'date': ['March 21, 2018'], 'body': 'Love yogurt came damaged -- foil lid punctured .', 'helpful': ['One person found this helpful']}, {'rating': ['5.0 out of 5 stars'], 'title': ['Tastes great, mixes well in smoothies.'], 'author': [], 'date': ['May 6, 2018'], 'body': 'A+ greek yogurt . We use product type yogurt zero points weight watchers .', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ["but I like the story behind the product and it's business strategy"], 'author': [], 'date': ['April 27, 2018'], 'body': "It 's yogurt . Nothing add , I like story behind product 's business strategy .", 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['January 12, 2018'], 'body': 'Use Sour Cream substitute -- also excellent starter homemade yogurt summer .', 'helpful': []}, {'rating': ['4.0 out of 5 stars'], 'title': ['Product quality as expected'], 'author': [], 'date': ['June 29, 2018'], 'body': 'Product quality expected', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['May 20, 2018'], 'body': 'Good', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['August 8, 2017'], 'body': 'This came fresh , cold delicious . I would purchase company & !', 'helpful': ['One person found this helpful']}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['July 30, 2018'], 'body': 'great', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ["Taste alot like Chick-fil-A's parfait!!!!"], 'author': [], 'date': ['December 24, 2016'], 'body': "Good stuff . I stirred bowl liquid splenda cut tartness wahlah ... smooth rich like silk whip cream . The texture smooth grit like others I tried . I 'm trying replicate Chick-fil-A 's yogurt far best brand match . All Greeks I tried tart . This perfect . I thinking I add maybe 1 tlbs regular yogurt 1 cup greek yogurt , splenda , dash vanilla , pinch salt make taste like Chick-fil-A 's . Will come back update review I find right consistency . 5 stars way Chobani .", 'helpful': ['3 people found this helpful']}, {'rating': ['5.0 out of 5 stars'], 'title': 
 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['RECOMMEND !'], 'author': [], 'date': ['October 29, 2017'], 'body': "Love Chobani yogurt - husband 's favorite . IMO best yogurt market one I buy .", 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Great tasting yogurt'], 'author': [], 'date': ['January 5, 2018'], 'body': 'Really liked yogurt ! Great taste price ok .', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['One of my favorites'], 'author': [], 'date': ['June 13, 2018'], 'body': 'One favorites', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['June 14, 2018'], 'body': 'Great product ! !', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['November 7, 2017'], 'body': 'good product thanks Amazon .', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['August 27, 2016'], 'body': 'great healthy snack', 'helpful': ['One person found this helpful']}, {'rating': ['4.0 out of 5 stars'], 'title': ['Four Stars'], 'author': [], 'date': ['March 29, 2018'], 'body': 'good taste', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Delicious! Best by is over a month out! :)'], 'author': [], 'date': ['March 4, 2016'], 'body': "This first order , I hesitant expiration dates ( 2 us , n't go groceries fast ) yogurt delicious ! The expiration month today , I 'm pleased !", 'helpful': ['2 people found this helpful']}, {'rating': ['4.0 out of 5 stars'], 'title': ['Good but runny'], 'author': [], 'date': ['July 30, 2017'], 'body': 'It tasted fine could less runny .', 'helpful': ['One person ...
# [{'rating': ['3.0 out of 5 stars'], 'title': ["It's ok"], 'author': ['SERA'], 'date': ['on August 22, 2018'], 'body': 'I think ok , kids love . There flavors Yoplait enjoy eating .', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': ['HAPPYORSAD'], 'date': ['on January 14, 2018'], 'body': 'ALL YUMMY !', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['February 27, 2017'], 'body': 'Great product ! Fast shipping delivery , well tasty !', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ["It's Good"], 'author': [], 'date': ['September 15, 2016'], 'body': "It 's Good", 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Good blueberry flavor'], 'author': [], 'date': ['September 29, 2016'], 'body': 'My kids love yogurt . Their favorite blueberry yoplait original , low-fat . And quick point difference try give .', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['December 11, 2016'], 'body': "Blueberries . Who live without 'em ?", 'helpful': []}, {'rating': ['4.0 out of 5 stars'], 'title': ['Easy to pack for a quick breakfast/snack'], 'author': [], 'date': ['August 13, 2016'], 'body': "Easy pack quick breakfast/snack . Ca n't go wrong yogurt . I wish come portable/disposable spoons .", 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['August 17, 2017'], 'body': 'Yummy !', 'helpful': []}, {'rating': ['3.0 out of 5 stars'], 'title': ['Three Stars'], 'author': [], 'date': ['July 17, 2017'], 'body': 'Average', 'helpful': []}, {'rating': ['4.0 out of 5 stars'], 'title': ['Four Stars'], 'author': [], 'date': ['August 18, 2017'], 'body': 'delicious', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['February 27, 2017'], 'body': 'Great product ! Fast shipping delivery , well tasty !', 'helpful': []}, {'rating': ['1.0 out of 5 stars'], 'title': ["it's literally\u200b full of s*** very bad for you"], 'author': [], 'date': ['August 22, 2016'], 'body': "This NOT real yogurt . Read ingredients label , 's literally\u200b full s*** bad .", 'helpful': ['One person found this helpful']}, {'rating': ['1.0 out of 5 stars'], 'title': ["Don't waist your money"], 'author': [], 'date': ['July 21, 2017'], 'body': "Pasteurized Grade A Reduced Fat Milk , Sugar , Strawberries , Modified Corn Starch , Kosher Gelatin , Natural Flavor , Pectin , Colored Carmine , Yogurt Cultures ( L. bulgaricus , S. thermophilus , L. acidophilus ) , Vitamin A Acetate , Vitamin D3 . 's GMO product", 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['January 31, 2017'], 'body': 'Always good product', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['September 24, 2017'], 'body': 'great', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['coolio'], 'author': [], 'date': ['January 23, 2017'], 'body': 'pretty bomb yogurt . yum', 'helpful': []}, {'rating': ['3.0 out of 5 stars'], 'title': ['Three Stars'], 'author': [], 'date': ['March 16, 2017'], 'body': 'I wish non-gmo taste delicious', 'helpful': []}, {'rating': ['4.0 out of 5 stars'], 'title': ['Packed with flavor'], 'author': [], 'date': ['November 13, 2017'], 'body': 'Yoplait Cherry Yogurt creamy packed flavor . I pleasantly surprised much yogurt tasted cherries . Our product arrived fresh well expiration date .', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Big chunks of cherry - oh yeah!'], 'author': [], 'date': ['December 2, 2016'], 'body': 'Arrived great expiration date several weeks . Good job , Amazon ! This flavor favorite Yoplait I love big chunks cherries . Smooth tasty .', 'helpful': []}, {'rating': ['5.0 out of 5 stars'], 'title': ['Five Stars'], 'author': [], 'date': ['July 9, 2016'], 'body': ': )', 'helpful': []}, {'rating': ['1.0 out of 5 ...

# %%
# print(col_dict)

# %%
import multiprocessing
from gensim.corpora.wikicorpus import WikiCorpus
from gensim.models.word2vec import Word2Vec

model_dict = {}

for key in col_dict:
    sentences = list([wd.split() for wd in list(col_dict[key]['body'])])
#     print(sentences)
    params = {'size': 200, 'window': 10, 'min_count': 5, 
              'workers': max(1, multiprocessing.cpu_count() - 1), 'sample': 1E-3,}
    word2vec = Word2Vec(sentences, **params)
    model_dict[key] = word2vec

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt


def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) &
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1]) 
    ]
     
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

def display_closestwords_tsnescatterplot(model):
    
    count = 10000
    word_vectors_matrix = np.ndarray(shape=(count, 200), dtype='float64')
    word_list = []
    i = 0
    for word in model.wv.vocab:
        word_vectors_matrix[i] = model[word]
        word_list.append(word)
        i = i+1
        if i == count:
            break
    tsne = TSNE(n_components=2, random_state=0)
    word_vectors_matrix_2d = tsne.fit_transform(word_vectors_matrix)
    print("word_vectors_matrix_2d shape is ", word_vectors_matrix_2d.shape)

    
    
    points = pd.DataFrame(
    [
        (word, coords[0], coords[1]) 
        for word, coords in [
            (word, word_vectors_matrix_2d[word_list.index(word)])
            for word in word_list
        ]
    ],
    columns=["word", "x", "y"]
    )
    print("Points DataFrame built")
    points.head(10)
    
    plot_region(x_bounds=(-2.2, -2.0), y_bounds=(-2.25, -2))

# %%
# print(model_dict['Plain Greek'].wv.vocab)
import seaborn as sns
# %matplotlib inline
for key in model_dict:
    
    
    display_closestwords_tsnescatterplot(model_dict[key])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
